# %%
import os, inspect
import re
from itertools import compress
import pandas as pd
import numpy as np
import datetime as dt
from time import time

# %%
CURR_DIR =  os.path.dirname(inspect.getabsfile(inspect.currentframe()))
ROOT_DIR =  os.path.dirname(CURR_DIR)

ffname = os.path.join(ROOT_DIR,"enron","data", "raw", 
                      "enron-event-history-all.csv")
df = pd.read_csv(
    ffname,
    header=None,
    converters= {
        0: lambda x: dt.datetime.fromtimestamp(int(x)/1000.0),
    },
    names=["datetime", "id", "sender", "recipients", "topic", "mode"],
    usecols=["datetime", "sender", "recipients"],
)

# df = df.loc[0:10000, :]
df.head()
# Out:
#              datetime              sender                     recipients
# 0 1998-05-27 17:31:00  Christopher Behney   Toni P Schulenburg|mary hain
# 1 1998-10-30 17:43:00   mark legal taylor  Marc.R.Cutler@BankAmerica.com
# 2 1998-10-30 17:56:00   mark legal taylor  Marc.R.Cutler@BankAmerica.com
# 3 1998-10-30 18:02:00   mark legal taylor                    shari stack
# 4 1998-10-30 19:06:00   mark legal taylor  Marc.R.Cutler@BankAmerica.com

# %%
df["date"] = df.datetime.dt.date
df["time"] = df.datetime.dt.time
df.head()

print("-"*30 + " columns " + "-"*30 + os.linesep)
print(repr(df.columns))
print("-"*30 + " shape" + "-"*30 + os.linesep)
print(df.shape)
print("-"*30 + " data types " + "-"*30 + os.linesep)
print(df.dtypes)
print("-"*30 + " top 5 rows " + "-"*30 + os.linesep)
df.head()
# Out:
# ------------------------------ columns ------------------------------
#
# Index(['datetime', 'sender', 'recipients', 'date', 'time'], dtype='object')
# ------------------------------ shape------------------------------
#
# (205731, 5)
# ------------------------------ data types ------------------------------
#
# datetime      datetime64[ns]
# sender                object
# recipients            object
# date                  object
# time                  object
# dtype: object
# ------------------------------ top 5 rows ------------------------------
#              datetime              sender                     recipients  \
# 0 1998-05-27 17:31:00  Christopher Behney   Toni P Schulenburg|mary hain
# 1 1998-10-30 17:43:00   mark legal taylor  Marc.R.Cutler@BankAmerica.com
# 2 1998-10-30 17:56:00   mark legal taylor  Marc.R.Cutler@BankAmerica.com
# 3 1998-10-30 18:02:00   mark legal taylor                    shari stack
# 4 1998-10-30 19:06:00   mark legal taylor  Marc.R.Cutler@BankAmerica.com
#
#          date      time
# 0  1998-05-27  17:31:00
# 1  1998-10-30  17:43:00
# 2  1998-10-30  17:56:00
# 3  1998-10-30  18:02:00
# 4  1998-10-30  19:06:00

# %%
# check on null rows
df.isnull().sum()
# Out:
# datetime       0
# sender        32
# recipients    38
# date           0
# time           0
# dtype: int64

# %%
# drop any rows with missing values (None) at 'sender' or 'recipients' columns
df.dropna(axis=0, how="any", subset=["sender", "recipients"], inplace=True)
df.head()
# Out:
#              datetime              sender                     recipients  \
# 0 1998-05-27 17:31:00  Christopher Behney   Toni P Schulenburg|mary hain
# 1 1998-10-30 17:43:00   mark legal taylor  Marc.R.Cutler@BankAmerica.com
# 2 1998-10-30 17:56:00   mark legal taylor  Marc.R.Cutler@BankAmerica.com
# 3 1998-10-30 18:02:00   mark legal taylor                    shari stack
# 4 1998-10-30 19:06:00   mark legal taylor  Marc.R.Cutler@BankAmerica.com
#
#          date      time
# 0  1998-05-27  17:31:00
# 1  1998-10-30  17:43:00
# 2  1998-10-30  17:56:00
# 3  1998-10-30  18:02:00
# 4  1998-10-30  19:06:00

# %%
# get two sparate columns for 'sendername' and 'senderat'
# df[["sendername", "senderat"]] = df.sender.str.split("AT", expand=True)

# %%
# convert all entries of 'sender'/'recipients' columns to lower case
def func(x):
    x = x.lower()
    x = x.replace('"', "")
    return x
df[["sender" , "recipients"]] = df[["sender" , "recipients"]].applymap(func)
df.head()
# Out:
#              datetime              sender                     recipients  \
# 0 1998-05-27 17:31:00  christopher behney   toni p schulenburg|mary hain
# 1 1998-10-30 17:43:00   mark legal taylor  marc.r.cutler@bankamerica.com
# 2 1998-10-30 17:56:00   mark legal taylor  marc.r.cutler@bankamerica.com
# 3 1998-10-30 18:02:00   mark legal taylor                    shari stack
# 4 1998-10-30 19:06:00   mark legal taylor  marc.r.cutler@bankamerica.com
#
#          date      time
# 0  1998-05-27  17:31:00
# 1  1998-10-30  17:43:00
# 2  1998-10-30  17:56:00
# 3  1998-10-30  18:02:00
# 4  1998-10-30  19:06:00

# %%
# tokenize the recipient column
df.recipients = df.recipients.str.split("|")
df.head()

# %%
# create recipients dataframe
df_recipients = pd.DataFrame(columns=["datetime", "recipient"])
for idx, row in df.loc[0:50, :].iterrows():
    df_recipients = pd.concat(
        [df_recipients, pd.DataFrame(data={"datetime":[row.datetime]*len(row.recipients),
                                           "recipient": row.recipients})],
        axis=0,
        ignore_index=True)

df_recipients

# %%
# create senders dataframe
df_senders = df[["datetime", "sender"]]
df_senders.head()

# %%
# Out:
#              datetime              sender                       recipients  \
# 0 1998-05-27 17:31:00  christopher behney  [toni p schulenburg, mary hain]
# 1 1998-10-30 17:43:00   mark legal taylor  [marc.r.cutler@bankamerica.com]
# 2 1998-10-30 17:56:00   mark legal taylor  [marc.r.cutler@bankamerica.com]
# 3 1998-10-30 18:02:00   mark legal taylor                    [shari stack]
# 4 1998-10-30 19:06:00   mark legal taylor  [marc.r.cutler@bankamerica.com]
#
#          date      time
# 0  1998-05-27  17:31:00
# 1  1998-10-30  17:43:00
# 2  1998-10-30  17:56:00
# 3  1998-10-30  18:02:00
# 4  1998-10-30  19:06:00

# %%
# get all unique person names in sender and recipients columns
unique_recipients = set()
def func(x, persons):
    persons.update(x)
_ = df.recipients.apply(func, args=(unique_recipients,))
sorted(unique_recipients)
idx = [True if "chris edmonds" in elem else False for elem in unique_recipients]
a = list(unique_recipients)
list(compress(a, idx))
# Out:
# ['chris edmonds@carvey.adgrafix.com', 'chris edmonds']

# %%
unique_senders = df.sender.unique()
unique_senders = set(unique_senders.tolist())
sorted(unique_senders)
# Out:
# ['*misc exchange customer activities\tcustomeractivities@gulfsouthpl.com@enron',
#  '.',
#  'a devries',
#  'aa wayne caa',
#  'aachazen caachazen',
#  'aagigian suffolk caagigian',
#  'aajoy t bpnfgry mailprograms delta',
#  'aaldous watarts uwaterloo',
#  'aamir maniar',
#  'aarbisser kayescholer',
#  'aaron armstrong',
#  'aaron berutti',
#  'aaron breidenbaugh caaron global',
#  'aaron brown',
#  'aaron chase cach netscape',
#  'aaron global',
#  'aaron gould',
#  'aaron klemm',
#  'aaron marks caamarks apmrecruiting',
#  'aaron martinsen',
#  'aaronmendelson',
#  'aazccb swbell',
#  'ab green',
#  'ab turbomail',
#  'abaird lemle',
#  'abarnett mapus',
#  'abb eslawfirm',
#  'abbewool cabbewool',
#  'abby discountair',
#  'abc euole eve',
#  'abc nyu cabc',
#  'abcnews l list starwave',
#  'abcny corp elaw',
#  'abcny corp law',
#  'aberm montreuxenergy',
#  'abh pge',
#  'abhijeet naik',
#  'abhitt mindspring',
#  'abigail taylor',
#  'ablanchard idgbooks',
#  'ablist about',
#  'ablumrosen',
#  'abmcdonald cabmcdon',
#  'abourne alec',
#  'abramson cami cabramson',
#  'abrock poloralphlauren',
#  'abrown iusb cabrown',
#  'abuchanan diversa cabuchanan',
#  'acaperton stargate',
#  'access cr xmr',
#  'access interactive ewsj',
#  'account update amazon',
#  'accountinfo datek',
#  'accountinformation community nextcard',
#  'accountit autorelister',
#  'accountmanager shockwave',
#  'accounts ezboard',
#  'accounts quickbase',
#  'accthelp cooltravelassistant',
#  'accthelp expedia',
#  'accthelp support eexpedia',
#  'accthelp support expedia',
#  'aceanthony excite caceanthony',
#  'acedirect aircanada',
#  'acej cacej',
#  'acevedo pablo',
#  'achokshi',
#  'achokshi firstcallassociates',
#  'achrisco prosrm',
#  'ack aelaw',
#  'ackc',
#  'aclark firstcallassociates',
#  'acomnes prodigy',
#  'acormier vicr',
#  'acqm wtkmafd',
#  'acrump dc',
#  'actforchange com',
#  'activeleads eudoramail',
#  'activelist admin eactivestate',
#  'activenrma eamunet',
#  'acton jan cjacton crai',
#  'acullen firstcallassociates',
#  'acunningham technologicp',
#  'acuou iobox efi',
#  'ada clickaction',
#  'ada takahashi cada kochgallery',
#  'adam and nicole lesser cfurie rocketmail',
#  'adam bayer',
#  'adam dyerson cadam edyerson gfinet',
#  'adam eudoramail',
#  'adam giannone',
#  'adam johnson',
#  'adam kulick',
#  'adam overfield',
#  'adam plager',
#  'adam siegel',
#  'adam umanoff',
#  'adam wais',
#  'adambob stat rice',
#  'adamk nepco',
#  'adams jacqueline cjacqueline eadams cinergy',
#  'adamsholly netscape',
#  'adanker kayescholer',
#  'adarsh vakharia',
#  'addyee caddyee',
#  'adel robinson',
#  'adela briner',
#  'adele raspe',
#  'adeller ercot',
#  'adesell nyiso',
#  'admin fsddatasvc',
#  'admin iwin',
#  'admin neteller',
#  'admin newmn blue',
#  'administrator internetex',
#  'administrator midwestdirectories',
#  'adminsec centralhouston',
#  'admissions amunet',
#  'adnan and maylynn khan cthe fkhans',
#  'adnan khan cakhan khanventures',
#  'adnan patel',
#  'adonnell prmllp',
#  'adrial boals',
#  'adrian clark caclark firstcallassociates',
#  'adrian mancebo',
#  'adrian montague',
#  'adrian woolcock',
#  'adriana wynn',
#  'adriane moratto',
#  'adriane schultea',
#  'adrianne engler',
#  'aduncan kilstock',
#  'advadv ruraltel',
#  'advapl vsnl',
#  'adventurehf pdq',
#  'adver passionboys',
#  'aefurcht facstaff ewisc caefurcht',
#  'aei bi fupdates www ebrook',
#  'aei fupdate caei update eorg',
#  'aei update',
#  'aelia isda eur',
#  'aeng aoshouston',
#  'aevanloon',
#  'af ssclxjfagjsrr travelocity',
#  'af@tfts.tozzini.com.br',
#  'af@tozzini.com.br',
#  'affelt',
#  'afield mariner',
#  'afilas keyspanenergy',
#  'afinch iasco',
#  'afinch natsource',
#  'aforbess wcenviro',
#  'afoster hampshire cafoster',
#  'aftab saleem',
#  'afterchristmas fspecial',
#  'afternic cafternic fsupport adm echtah',
#  'aga rehman',
#  'agallers cagallers',
#  'agatha tran',
#  'agaur tjbc ecoj cagaur',
#  'agbriggs adamswells cagbriggs',
#  'agent manager',
#  'agentrapid pacbell',
#  'aggie chic',
#  'aggienetwork',
#  'agnews cme americangreetings',
#  'agoddard nisource',
#  'agovenar govadv',
#  'agrasso ml',
#  'agustin perez',
#  'ahafner csc',
#  'ahampshire cowan howard',
#  'ahand tambank cahand',
#  'aharpaz doverinstrument caharpaz',
#  'aherbst utilisenergy',
#  'ahespenh cahespenh',
#  'ahimsaom cs cahimsaom',
#  'ahockman attbroadband cahockman',
#  'ahopp mercator cahopp',
#  'aiaz kazi versata',
#  'aiazkazi hotbot',
#  'aidenfire mediaone',
#  'aile caile mailman eenron',
#  'aimee lannou',
#  'aimr scholarship fund caimr bbh eviamedialinq',
#  'airam arteaga',
#  'airmail xmr',
#  'airmessage',
#  'aisha jamal',
#  'aivvxx',
#  'aiysha billings cabillings knowledgeinenergy',
#  'ajax planet save cajax',
#  'ajay jagsi',
#  'ajlbrgaeimh drqpu pauf iokfr travelocity',
#  'ajones uwtgc',
#  'akasha redrick',
#  'akatz eei',
#  'akeiser rocketmail',
#  'akht sjzvc',
#  'akimball bracepatt',
#  'akoelemay cogc',
#  'akoenig hhw law',
#  'akorth',
#  'akwete hines',
#  'al alexanderson',
#  'al arfsten carfsten bflassociates',
#  'al colangelo',
#  'al epollard newpower',
#  'al herrmann',
#  'al maawali',
#  'al v andrew cmu',
#  'alaadin suliman',
#  'alain diza',
#  'alaina doublemo',
#  'alamo',
#  'alamonsoff riskwaters',
#  'alamonsoff watersinfo',
#  'alan aronowitz',
#  'alan batt oxy',
#  'alan bransgrove',
#  'alan chapman',
#  'alan chen',
#  'alan comnes',
#  'alan engberg',
#  'alan enventure',
#  'alan jones',
#  'alan jr',
#  'alan julson cvze szx verizon',
#  'alan larsen',
#  'alan lucks clucks alucks',
#  'alan mcgaughy',
#  'alan pacbell',
#  'alan wayne',
#  'alan yudkowsky',
#  'alaska web',
#  'albernita travis',
#  'albert escamilla',
#  'albert hernandez',
#  'albert luc',
#  'alberta realtime',
#  'alberto jaramillo putnaminv',
#  'alberto levy',
#  'alcantara',
#  'aleck dadson',
#  'alejandra chavez',
#  'alejandro hernandez',
#  'aleonard caiso',
#  'alerts breakingnews',
#  'alerts equityalert',
#  'alerts finance',
#  'alerts stock',
#  'alerts stockselector',
#  'alevwho mediaone calevwho',
#  'alex ehuang',
#  'alex eplanning',
#  'alex hidalgo',
#  'alex huang',
#  'alex saldana',
#  'alex schott cfatschott',
#  'alex wong',
#  'alexander mcelreath',
#  'alexandra cameron',
#  'alexandra saler',
#  'alexandra tgharchs calexandra',
#  'alexandra villarreal',
#  'alexandra villarreal cavillarreal err',
#  'alexandre bueno',
#  'alexanms sce',
#  'alexeaton',
#  'alexeaton calexeaton',
#  'alexia gonzales',
#  'alexia pearce',
#  'alexios kollaros',
#  'alexis calexis',
#  'alexus rhone',
#  'alfred koenig cakoenig hhw law',
#  'alfred pennisi',
#  'alfredo dvinci',
#  'alfredo huertas',
#  'algoreply algorithmics',
#  'alhamd alkhayat',
#  'ali panix cali',
#  'aliban uol eco ees',
#  'alice barton cenergy flist spencerstuart',
#  'alice gruber cagruber tindallfoster',
#  'alice hritz',
#  'alice johnson',
#  'alice wright',
#  'alicia allrecipes calicia',
#  'alicia perkins',
#  'alienenvoy',
#  'alisa green',
#  'alisha bp',
#  'alisha guerrero',
#  'alisha mahabir',
#  'alishec calishec',
#  'alison campbell eott',
#  'alison keogh',
#  'alison tomb',
#  'alistair coleman',
#  'all enron',
#  'alla gil',
#  'allactivema eamunet',
#  'allactivestudents eamunet',
#  'allan',
#  'allan roberts',
#  'allan severude',
#  'allan sommer',
#  'alldirect chelp',
#  'allen joe',
#  'allen ueckert',
#  'allenste rcn',
#  'allfreenews newsletter callfreenews epostlite',
#  'alli parent',
#  'allibakke callibakke',
#  'allison',
#  'allison firstconf',
#  'allison martin calliemartin',
#  'allison mchenry',
#  'allison millan',
#  'allison navin',
#  'allmybestestfriends com',
#  'allolduserstext owner newsletter eussoccer',
#  'alluserstext owner newsletter eussoccer',
#  'ally waika',
#  'allyoucanink cspecial flowgo',
#  'allyson lafave cghpinvite x www eimakenews',
#  'allyson zykorie',
#  'alma carrillo',
#  'alma green',
#  'almeida',
#  'almeida keoni',
#  'almeida keoni ckalmeida caiso',
#  'alok garg',
#  'alonesgroupinc',
#  'alonesgroupinc gateway',
#  'alove cs',
#  'altacharo caltacharo',
#  'altavista se',
#  'altcap rogers',
#  'alterson thomas jpmorgan',
#  'althea gordon',
#  'althouses calthouses',
#  'altonh swiftenergy',
#  'alucio vertical',
#  'alumni tlu',
#  'alumoff anderson ucla',
#  'alvin thompson',
#  'alynda fwheat fortunemail',
#  'alyons mindspring calyons',
#  'alyse herasimchuk',
#  'alysia pickens',
#  'alyssa irving',
#  'amador',
#  'amador granado',
#  'amalmsjo rwbeck',
#  'amanda curless',
#  'amanda cvivatrim open win eroi',
#  'amanda day',
#  'amanda huble',
#  'amanda keiser',
#  'amanda rybarski',
#  'amanda schear',
#  'amanda schultz',
#  'amanda talbot',
#  'amandawhitby coolgoose',
#  'amazon',
#  'amazon cbook',
#  'amazon celectronics',
#  'amazon cgift',
#  'amazon cnew for you',
#  'amazon cpartner',
#  'amazon cshowtimes',
#  'amazon csoftware',
#  'amazon cstore',
#  'amazon delivers action dvd cdelivers',
#  'amazon delivers cdelivers',
#  'amber ebow',
#  'amber keenan',
#  'amber limas',
#  'amber mcgown cadmcgown ev',
#  'ambriz annette cannette eambriz compaq',
#  'ambrocik',
#  'amc incentre',
#  'amcc',
#  'amccarty',
#  'amcconn csc',
#  'ameasom ccsystems',
#  'ameerabu',
#  'ameerabuhalimeh bankunited',
#  'amelia alder',
#  'amelia alland',
#  'amelia williams',
#  'ameliapower cameliapower',
#  'amendels@lehman.com',
#  'american airlines aairmail caairmail eaa',
#  'american airlines aairmail cairmail xmr',
#  'american express',
#  'american express colrr eamericanexpress',
#  'american flags cnewsletter quickinspirations',
#  'amerikosus',
#  'ameritrade',
#  'ameritrade cameritrade ecustomer',
#  'ameritrade new accounts cstarting',
#  'amexaefa americanexpress',
#  'amexcheckyourbill americanexpress',
#  'ameyer wii',
#  'ameytina bear',
#  'ami chokshi',
#  'ami chokshi cachokshi firstcallassociates',
#  'ami thakkar',
#  'amicaliz sda uni bocconi it',
#  'amin maredia',
#  'amirault paul cpaulamirault aec eca',
#  'amita gosalia',
#  'amitava dhar',
#  'amkilpat southernco',
#  'amontalbano pyatok camontalbano',
#  'amos pettingill',
#  'amosher appanet',
#  'amosley houston',
#  'amr ibrahim',
#  'amunet',
#  'amy ashburn caashburn mindspring',
#  'amy baker',
#  'amy brock camy ebrock halliburton',
#  'amy clemons',
#  'amy cooper',
#  'amy copeland',
#  'amy degeyter',
#  'amy eblumrosen bakerbotts',
#  'amy epis',
#  'amy fabian',
#  'amy felling',
#  'amy fitzpatrick',
#  'amy florusso timeinc',
#  'amy fyueh agfg',
#  'amy gambill',
#  'amy hood camy ehood ebrann',
#  'amy jon',
#  'amy kvo camy',
#  'amy lee',
#  'amy mulligan',
#  'amy oberg',
#  'amy quirsfeld',
#  'amy rios',
#  'amy shreck eshreck occmail eocc estate eok eus',
#  'amy siedenburg',
#  'amy smith',
#  'amy spoede',
#  'amy stern camystern earthlink',
#  'amy thehallagency',
#  'amyb activate camyb',
#  'amyf review',
#  'amys planetkc',
#  'amywilson btamail',
#  'amywilson btamail ecn',
#  'amywohlsein uty',
#  'an',
#  'an la can',
#  'an nationalpublishing',
#  'ana alcantara',
#  'ana castanon',
#  'ana hernandez',
#  'ana rizvi',
#  'anabel soria',
#  'anabella sousa',
#  'anand david',
#  'anastasia aourik',
#  'anastasia omegamoulding canastasia',
#  'ancestry cmediatrec emailfactory',
#  'ancestry cmessenger smartreminders',
#  'anchordesk canchordesk fdaily ezdlists',
#  'anders ryrfeldt',
#  'andersen pjm',
#  'anderson',
#  'anderson donna cdonna fanderson aimfunds',
#  'andre templeman',
#  'andrea andries',
#  'andrea bertone',
#  'andrea calo',
#  'andrea calo/enron_development at enron_development@ccmail',
#  'andrea crump',
#  'andrea dahlke',
#  'andrea flueders candrea',
#  'andrea guillen',
#  'andrea reed',
#  'andrea richards',
#  'andrea ring',
#  'andrea settanni',
#  'andrea shane candishane pol',
#  'andrea stein',
#  'andrea streight',
#  'andrea walters cawalters',
#  'andrea williams',
#  'andrea williams cawilliam skadden',
#  'andrea williams ctwilliams evi',
#  'andrea yowman',
#  'andreahelling',
#  'andreas garpmail',
#  'andreas kraus',
#  'andreas schoepf',
#  'andreas simou',
#  'andreasea candreasea',
#  'andrei swapsmonitor',
#  'andrew bracken',
#  'andrew branan',
#  'andrew branan candrew ebranan creativeloafing',
#  'andrew champion',
#  'andrew conner',
#  'andrew cornfield',
#  'andrew douglass candrewd tex trude',
#  'andrew eclark weil',
#  'andrew edison',
#  'andrew eharting weil',
#  'andrew elloyd ubsw',
#  'andrew enronxgate',
#  'andrew fairley',
#  'andrew fastow',
#  'andrew gibbins',
#  'andrew gieser',
#  'andrew greer',
#  'andrew harting',
#  'andrew henderson',
#  'andrew kandolha',
#  'andrew kelemen',
#  'andrew kosnaski',
#  'andrew lewis',
#  'andrew lewis cahl',
#  'andrew miles',
#  'andrew miller ccathylendel canada',
#  'andrew parsons',
#  'andrew schuleman',
#  'andrew schwed',
#  'andrew slocum candrews calpine',
#  'andrew thomas',
#  'andrew wilson',
#  'andrew wu',
#  'andrewhescock',
#  'andrews',
#  'andrews calpine',
#  'andrewswhitman',
#  'andria stevens',
#  'andy blanchard',
#  'andy brady',
#  'andy colman candy spectronenergy',
#  'andy kelly',
#  'andy pace',
#  'andy rodriquez',
#  'andy shackouls cashackouls',
#  'andy siegel casiegel questia',
#  'andy unverzagt',
#  'andy weingarten candy apbenergy',
#  'andy zipper',
#  'andylee hkem',
#  'aneela charania',
#  'ang li',
#  'angel esguerra',
#  'angel flight south central pilots list angelflightsc',
#  'angel martinez',
#  'angel txucom cangel',
#  'angela barnett',
#  'angela cadena',
#  'angela davis',
#  'angela davis agc',
#  'angela dorsey',
#  'angela hylton',
#  'angela lehew calehew sequentenergy',
#  'angela mcculloch',
#  'angela morris',
#  'angela nicotra',
#  'angela palmieri',
#  'angela ramirez hou azurix',
#  'angela smith',
#  'angela soundmediagroup',
#  'angela white',
#  'angela williams',
#  'angela wilson',
#  'angela wright cangela ewright truequote',
#  'angelia guinara cguinara',
#  'angelic davis',
#  'angelictouch cangelictouch',
#  'angelina lorio',
#  'angeline poon',
#  'angelo miroballi',
#  'angie buis',
#  'angie collins',
#  'angie gillikin cangiegillikin',
#  'angie hueca',
#  'angie lentz',
#  'angie nicastro',
#  'angie zeman',
#  'angieb',
#  'angiez',
#  'angusmcka',
#  'anil sama',
#  'anita dupont',
#  'anita fam',
#  'anita fanthony ziffdavis canita',
#  'anita llamas',
#  'anita luong',
#  'anita martin',
#  'anita parker',
#  'anita worth canita prescottlegal',
#  'anitha mathis',
#  'anjam ahmad',
#  'anji bordelon',
#  'ankush sen',
#  'ann ballard',
#  'ann brown',
#  'ann carethers',
#  'ann cohn',
#  'ann consulair cann',
#  'ann elizabeth',
#  'ann es echen accenture',
#  'ann makris',
#  'ann monshaugen',
#  'ann mora',
#  'ann osire',
#  'ann schmidt',
#  'ann smith',
#  'ann stagg cann estagg biosgroup',
#  'ann vaughn',
#  'anna allen',
#  'anna brown cpmjr',
#  'anna confidential',
#  'anna fball patagonia canna',
#  'anna fnorville canna',
#  'anna fox',
#  'anna goldberg cannamgoldberg',
#  'anna jansson',
#  'anna mcandrew',
#  'anna mehrer',
#  'anna santucci',
#  'annabelle brown',
#  'annas cobs',
#  'annasymes',
#  'annat jain cannat thotcapital',
#  'annat jain cannatjain',
#  'annawilliams btamail',
#  'annawilliams btamail ecn',
#  'annbertino',
#  'anncrawford aec',
#  'anne beliveaux',
#  'anne bike',
#  'anne blackman',
#  'anne burch',
#  'anne clark',
#  'anne eastwood',
#  'anne filas cafilas keyspanenergy',
#  'anne hicks',
#  'anne jolibois',
#  'anne koehler',
#  'anne labbe',
#  'anne marie',
#  'anne marie wheeler cawheeler onetel euk',
#  'anne moisan canne emoisan internationalsos',
#  'anne moisan cannemoisan',
#  'anne snyder pgn',
#  'annelaurance mediaone cannelaurance',
#  'anneleuthold techtvcorp',
#  'annemarie allex',
#  'annemieke slikker',
#  'annemwang excite cannemwang',
#  'annette espencer ubsw',
#  'annette schneider',
#  'annie page',
#  'annie r jones cajones uwtgc eorg',
#  'annieleung kpmg',
#  'annmarie tiller',
#  'announce highschoolalumni',
#  'announce list clearchannel',
#  'announcement popularlink',
#  'announcements',
#  'announcements cc cannounce list clearchannel',
#  'announcements datek',
#  'announcements provantage',
#  'announcements welcome ebay',
#  'anntares canntares',
#  'annual reports service pbg wzqjfq wilink eacc',
#  'annualconference prosrm',
#  'annualgiving aggienetwork',
#  'ano kw boshra cano',
#  'anonymous canonymous advicebox',
#  'another one cexenron',
#  'anoush farhangi',
#  'anshuman srivastav',
#  'anthony campos',
#  'anthony dayao',
#  'anthony duenner',
#  'anthony ebrown ubsw',
#  'anthony jarrett',
#  'anthony leitner',
#  'anthony mends',
#  'anthony robert crobert eanthony brookwoods',
#  'anthony sexton',
#  'anthony targan ctargana dteenergy',
#  'anthony tran',
#  'antigen mailman eenron',
#  'antik cantik gateway',
#  'antiknewyork',
#  'antiqstyle',
#  'antlulu',
#  'antoine duvauchelle',
#  'antoinette beale',
#  'antoinetteml cantoinetteml',
#  'antonio paez',
#  'antonio paez cpaez',
#  'antonio tanpoco catanpoco telesto',
#  'antonio vergara',
#  'anurag saksena',
#  'anwar melethil',
#  'anya beylin',
#  'aoc pacbell caoc',
#  'aociep sgh waw pl',
#  'aod newsdata',
#  'aol instant',
#  'aolanywheregames pogo',
#  'aopa',
#  'aopa epilot',
#  'aosawa attglobal',
#  'apache capache supertaf',
#  'apacheco oneok',
#  'apalmerlee cfr',
#  'apanasko manfinancial',
#  'apapesch isda',
#  'aparna rajaram',
#  'apatel nsi capatel',
#  'apbatra',
#  'apeterson wildoats capeterson',
#  'aplldd',
#  'apogue bust capogue',
#  'apollo',
#  'appdev training cproductdev eappdev',
#  'appelled apci cappelled',
#  'apple enews capple fenews applenews elists eapple',
#  'applicationservice bdcimail',
#  'appling',
#  'approval dept cmezmoot',
#  'april hrach',
#  'april weatherford',
#  'aprilhoover caprilhoover',
#  'apsc',
#  'araceli romero',
#  'arader',
#  'araemurphy caraemurphy',
#  'aram sogomonian',
#  'archwireless',
#  'arcy carroll',
#  'arcy carroll sa',
#  'ardorny',
#  'are you ready ccrushmaster monstercrush',
#  'arebil webtv carebil',
#  'arfan aziz',
#  'arfsten bflassociates',
#  'ariail jr robert mills cmills eariail odnss',
#  'ariana cmarciannax w gomail eua',
#  'ariane saney',
#  'arianna fking rsconst carianna',
#  'arie arik amir carik business',
#  'ariel cerantola',
#  'arlanz mexis',
#  'arlanz mexis armando lanz',
#  'arlanz mexis comarlanz armando lanz',
#  'arlgin',
#  'armandd ben dev upenn',
#  'armando guerra carmy',
#  'armando martinez cmondohed gte',
#  'armeguy pacbell',
#  'armstrong',
#  'armstrong cynthia ccarmstrong spragueenergy',
#  'army',
#  'arnie bailey',
#  'arnold eisenstein',
#  'arnold paxton',
#  'arnold stifel',
#  'arnold truax catruax dot estate etx eus',
#  'array networks carray ssprd',
#  'arshak sarkissian',
#  'arsystem',
#  'art bieser',
#  'art shaw cart mycfo',
#  'arta',
#  'arta carta err',
#  'arteaga',
#  'arthur boytinck caboytinck emsn',
#  'arthur donnell caod newsdata',
#  'arthur goldsmith',
#  'arthur ransome',
#  'arthur tiffany ctarthur iinvestor',
#  'artic',
#  'articles ms elga enytimes',
#  'artistchar cartistchar',
#  'artistdirect cartistinsider eartistdirect',
#  'aruckdes caruckdes',
#  'arun balasundaram',
#  'arvel martin',
#  'arvind ramanathan',
#  'asaenz',
#  'asako takesaki',
#  'asama',
#  'asc interactivemarketing',
#  'asem atta',
#  'asettanni bracepatt',
#  'ash menon',
#  'ashford',
#  'ashley baxter',
#  'ashley brochstein',
#  'ashley fay',
#  'ashley kerr',
#  'ashley landry',
#  'ashley love calove err',
#  'ashley worthing',
#  'ashok mehta',
#  'ashton mjmcreative cashton',
#  'ashu tewari',
#  'ashwani kumar cakumar del evsnl ein',
#  'asjieq polbox',
#  'askinfamilyis',
#  'askus entertainment',
#  'asme cei list',
#  'asme pd list',
#  'asme pvrc list',
#  'asokan',
#  'asorelle h',
#  'asouth',
#  'aspring epsa',
#  'assemblyman keith richman csabina',
#  'assignee notification',
#  'assignee support',
#  'assignee support pwcglobal judy l wood',
#  'association eof epatent elaw efirms binfo aplf eorg',
#  'association pat',
#  'association.of.pat@aplf.org]',
#  'astacy@remedy.com',
#  'astevenson ida castevenson',
#  'astewar csc',
#  'astiner tiffany',
#  'astorey nyiso',
#  'astorey nyiso ees',
#  'at t wireless and worldcom ccpa oihost',
#  'at t wireless cspecialoffers iexpect',
#  'atafallo csc',
#  'atherton',
#  'athomas',
#  'athomas newenergy',
#  'atkinson whytecliff',
#  'atownley catownley',
#  'atrade ccustomers etrade mm',
#  'atrade cetrade esurvey mm',
#  'atrade cetradeservice etrade mm',
#  'atrade financial cetradeservice etrade mm',
#  'atrjknf cieq',
#  'atruppin mindspring catruppin',
#  'attglobal',
#  'attorneysed',
#  'attrecipeh emsiweb',
#  'atwood',
#  'au de pudsv',
#  'au eru',
#  'auburnandel cauburnandel',
#  'auctionary',
#  'audible caudible customoffers',
#  'audible caudible zzz',
#  'auditalk cauditalk audi',
#  'audkim cats eucsc caudkim',
#  'audrey cook',
#  "audrey o'neil",
#  'audrey robertson',
#  'augusto failde',
#  'aunverzagt',
#  'aurora dimacali',
#  'austin roger craustin alleghenypower',
#  'authorized personnel coffer americanbranding enetwork',
#  'authorized personnel cunsubscribe i networkpromotion',
#  'auto confirm amazon',
#  'auto service eloan',
#  'autolist cautolist lntercasino',
#  'automated response',
#  'automatedmail mplanners',
#  'autoweb',
#  'autumn cartier eott',
#  'ava garcia',
#  'avalon northwest wine cavalon avalonwine',
#  'avalon northwest wine cjean avalonwine',
#  'avalos art caavalos pnm',
#  'avanleunen cavanleunen',
#  'avantgo ckc kc mx eavantgo',
#  'avantgo enews cmarketing avant',
#  'avantgo wsjcom',
#  'avenueb',
#  'avenueb cenron',
#  'avenueme cavenueme customoffers',
#  'avi hauser',
#  'aviblack caviblack',
#  'avillarreal',
#  'avril forster',
#  'aw confirm ebay',
#  'awagner kayescholer',
#  'awais omar',
#  'awaskow ml',
#  'awe caiso',
#  'aweisbar fas eharvard caweisbar',
#  'aweissman energyvg',
#  'aweller sel',
#  'awenda cs',
#  'awilliam skadden',
#  'awitness',
#  'axisteam',
#  'ayesha kanji',
#  'aysu',
#  'ayudkowsky stroock',
#  'ayueh',
#  'ayw georgetown cayw',
#  'azam mistry',
#  'b palmer',
#  'b scott',
#  'b todes',
#  'baaramyoo cbaaramyoo',
#  'bab pacbell',
#  'backroads update',
#  'baddream cbaddream',
#  'badedamola cera',
#  'badether cbadether',
#  'bafjjfjefmbfzef cs',
#  'bagray calpx',
#  'baileatha cbaileatha',
#  'baker',
#  'baker donna cdbaker group auto',
#  'baker james cjames ebaker ubsw',
#  'baldtimwin cbaldtimwin',
#  'balfour flanagan',
#  'ball aipe',
#  'balladeer att',
#  'balletstar',
#  'ballou chris cchris fballou bmc',
#  'balson william cwbalson crai',
#  'bambi heckerman',
#  'bambos stanford',
#  'bamiller kpmg',
#  'bamoroso wfubmc cbamoroso',
#  'ban sharma',
#  'bandersn loyno cbandersn',
#  'bani arora',
#  'banin saar csaar ebanin gs',
#  'banu ozcan',
#  'baran',
#  'barbara bennett',
#  'barbara bischoff',
#  'barbara cain',
#  'barbara clancey',
#  'barbara dillard',
#  'barbara eustis cbeustis romcapital',
#  'barbara ewaldrop cox',
#  'barbara fmorgen aigi',
#  'barbara gray',
#  'barbara hankins',
#  'barbara hueter',
#  'barbara lee',
#  'barbara lewis',
#  'barbara martinez',
#  'barbara martinez de sanchez cbar bara',
#  'barbara ostdiek costdiek rice',
#  'barbara paige',
#  'barbara sain',
#  'barbara vandervliet cbarblpl',
#  'barbara waldrop',
#  'barbaranielsen dwt',
#  'barbe robin crobin ebarbe',
#  'barbette watts i',
#  'barbour',
#  'bardblack',
#  'barend vanderhorst',
#  'barkerde nmenergy',
#  'barnes',
#  'barnes noble cbncom ebn',
#  'barnesfamilyus prodigy',
#  'barrett management wharton upenn',
#  'barry brunelle cbbrunel smud eorg',
#  'barry crouch cbcrouch',
#  'barry pearce',
#  'barry pearce communications',
#  'barry tycholiz',
#  'bart burk',
#  'bart fculuhmk',
#  'bart jones transalta',
#  'bart monden',
#  'bartlett',
#  'bartlette utexas',
#  'bartlo noel cnoel ebartlo elpaso',
#  'bartneea bp',
#  'barton clark',
#  'bartvonsimpson cbartvonsimpson',
#  'baslerasoc cbaslerasoc',
#  'bass',
#  'basswtrout pacbell',
#  'bastida',
#  'bat oggero cbat sshdesign',
#  'bat oggero cbatoggero',
#  'bates',
#  ...]

# %%
# check if there are shared persons between senders and recipients
len(unique_senders.intersection(unique_recipients))
# Out:
# 7577

# %%
persons = set.union(unique_recipients, unique_senders)
sorted(persons)
# Out:
# ['',
#  ' - *joan.veselack@enron.com',
#  ' - *murex@manado.wasantara.net.id',
#  ' - *porter, jeffrey',
#  ' - *stiles, marianne',
#  "'andrea.v.reed@enron.com' <andrea.v.reed, 'anne.c.koehler@enron.com'<anne.c.koehler,>",
#  "'e201b-2@haas.berkeley.edu'",
#  "'esarte@haas.berkeley.edu'",
#  "'jdasovic@enron.com' <jdasovic, williams,>",
#  "'lpliska@haas.berkeley.edu'",
#  ')bob.m.hall@enron.com',
#  '*misc exchange customer activities\tcustomeractivities@gulfsouthpl.com@enron',
#  '-',
#  '.',
#  '105954@mailman.enron.com',
#  '94094@mailman.enron.com',
#  '\\ \\\\\\ dylan windham\\\\',
#  '\\ dylan windham\\  <smtp:dwindham@uclink4.berkeley.edu> <dylan windham',
#  'a capolongo',
#  'a devries',
#  'a gelotti',
#  'a matheson',
#  'a peshkoff',
#  'a ponce',
#  'a zeutzius',
#  'a-l-brian@fred.masterpage.com.pl',
#  'aa',
#  'aa aae ed',
#  'aa ae ac',
#  'aa cc',
#  'aa cc fe',
#  'aa ccf',
#  'aa dd ae',
#  'aa de',
#  'aa ea',
#  'aa ed ea',
#  'aa ee bf',
#  'aa efb',
#  'aa fd fb',
#  'aa fe',
#  'aa ffd',
#  'aa sbc',
#  'aa txmail sbc',
#  'aa wayne caa',
#  'aababp pplweb',
#  'aabbate metromediaenergy',
#  'aabbcece airmail',
#  'aabbey camdenprop',
#  'aabraham',
#  'aachazen caachazen',
#  'aad ebc',
#  'aada dynegy',
#  'aadams',
#  'aadamson nycap',
#  'aadedeji risk uk',
#  'aadovasio newscorp',
#  'aafaa',
#  'aafb fdb',
#  'aagigian suffolk caagigian',
#  'aagrawal',
#  'aagrawal cba ua',
#  'aagudelo',
#  'aahill kmpg',
#  'aahmad',
#  'aahmed',
#  'aajoy t bpnfgry mailprograms delta',
#  'aalavi metamor its',
#  'aaldous watarts uwaterloo',
#  'aalkhay',
#  'aalmazan utexas',
#  'aamacewen dow',
#  'aamir maniar',
#  'aamirali caiso',
#  'aamron wexford',
#  'aandrews gie',
#  'aandsnath',
#  'aaoliver utmb',
#  'aarbisser kayescholer',
#  'aare vp directors and managers',
#  'aaric foree',
#  'aarmstrong sempratrading',
#  'aaron',
#  'aaron armstrong',
#  'aaron berutti',
#  'aaron breidenbaugh caaron global',
#  'aaron breidenbaugh rmiinc',
#  'aaron brown',
#  'aaron chase cach netscape',
#  'aaron comaltexins',
#  'aaron global',
#  'aaron gould',
#  'aaron jang',
#  'aaron kirsten',
#  'aaron klemm',
#  'aaron lowe',
#  'aaron marks caamarks apmrecruiting',
#  'aaron martinsen',
#  'aaron nelson',
#  'aaron prlcny',
#  'aaron qeraser',
#  'aaron roffwarg',
#  'aaron stai',
#  'aaron thomas',
#  'aaronmendelson',
#  'aarons aberrant',
#  'aarons horizoncapitalbank',
#  'aarteag',
#  'aashburn mindspring',
#  'aashburn mindspring samy ashburn',
#  'aatta',
#  'aavalos epelectric',
#  'aavalos pnm',
#  'aavalos pnm avalos art caavalos',
#  'aaybarra utmb',
#  'aazccb swbell',
#  'ab',
#  'ab acb ae',
#  'ab da fa dd',
#  'ab dd',
#  'ab ea cbefb',
#  'ab eba',
#  'ab eec',
#  'ab fc db',
#  'ab fcf',
#  'ab green',
#  'ab netposta',
#  'ab turbomail',
#  'aba',
#  'aba bdeb',
#  'aba fc',
#  'aba vnf',
#  'abadijr texaco',
#  'abag cta',
#  'abaird lemle',
#  'abakarich renfrew insurance',
#  'abalberg houserv',
#  'aballar',
#  'abarnett',
#  'abarnett mapus',
#  'abarryrand',
#  'abasur sprintspectrum',
#  'abaxter qwest',
#  'abaxter uswest',
#  'abayer',
#  'abb ec',
#  'abb eslawfirm',
#  'abba gana',
#  'abbate',
#  'abbewool cabbewool',
#  'abbiii pdq',
#  'abbott',
#  'abboudy',
#  'abby discountair',
#  'abbyb usgt',
#  'abbylopez pdq',
#  'abc euole eve',
#  'abc nyu cabc',
#  'abcb dec cf',
#  'abcnews l list starwave',
#  'abcny corp elaw',
#  'abcny corp law',
#  'abcny majordomo law',
#  'abdmoulaie',
#  'abdullah',
#  'abe riazati',
#  'abecb',
#  'abel',
#  'abenton utilicorp',
#  'aberdy',
#  'aberm montreuxenergy',
#  'abernath',
#  'abernathj@haas.berkeley.edu',
#  'aberton ei',
#  'aberutti',
#  'aberzins rwbeck',
#  'abf',
#  'abh pge',
#  'abhickman',
#  'abhijeet naik',
#  'abhitt mindspring',
#  'abhyankar',
#  'abi nix',
#  'abiecunasb prpa',
#  'abigail taylor',
#  'abike',
#  'abilla',
#  'abillings knowledgeinenergy aiysha billings cabillings',
#  'abizar shahpurwala',
#  'ablanchard idgbooks',
#  'ablanco',
#  'abler',
#  'ablist about',
#  'ablumden smartenergy',
#  'ablumrosen',
#  'abm',
#  'abmcdon',
#  'abmcdonald cabmcdon',
#  'aboals',
#  'aboerrs repsol ypf',
#  'abourne alec',
#  'aboytinck',
#  'abradford petersco',
#  'abraham',
#  'abraham solomon',
#  'abrahams',
#  'abramo',
#  'abramowicz',
#  'abrams',
#  'abramson cami cabramson',
#  'abreco ix netcom',
#  'abremner ipams',
#  'abressani bancofrances ar',
#  'abrock poloralphlauren',
#  'abrock poloralphlauren brock alex cabrock',
#  'abrown',
#  'abrown iusb',
#  'abrown iusb cabrown',
#  'abrown redstonebank',
#  'abs psu',
#  'abshire',
#  'abshirek epenergy',
#  'absteen dakotacom',
#  'abu bundu',
#  'abuchanan diversa cabuchanan',
#  'abuckley wutc wa',
#  'aburlina',
#  'aburrell utilicorp',
#  'abuxton preti',
#  'ac',
#  'ac bb',
#  'ac be ce',
#  'ac dc ab',
#  'ac world guava ease lsoft',
#  'aca',
#  'aca aa',
#  'acaa',
#  'acampbell reliant',
#  'acampos',
#  'acaperton stargate',
#  'acarpentier pyapc',
#  'acarril',
#  'acavazos',
#  'acba',
#  'acba bc',
#  'access cr xmr',
#  'access interactive ewsj',
#  'account update amazon',
#  'accountinfo datek',
#  'accountinformation community nextcard',
#  'accountit autorelister',
#  'accountmanager shockwave',
#  'accounts ezboard',
#  'accounts quickbase',
#  'acctdept alaweb',
#  'accthelp cooltravelassistant',
#  'accthelp expedia',
#  'accthelp support eexpedia',
#  'accthelp support expedia',
#  'ace may',
#  'ace roman',
#  'aceanthony excite caceanthony',
#  'acedirect aircanada',
#  'acej cacej',
#  'acevedo',
#  'acevedo pablo',
#  'aceversull',
#  'acf sopris',
#  'acff',
#  'achaber entergy',
#  'achampi',
#  'acharan',
#  'achau tractebelpowerinc',
#  'achavez',
#  'achen',
#  'acherzer optonline',
#  'achilders calpine',
#  'achimlindhorst',
#  'achimlindhorst mgrecycling mgltd',
#  'achin colcnr',
#  'achokshi',
#  'achokshi firstcallassociates',
#  'achowdry transenergy',
#  'achrisco prosrm',
#  'achu',
#  'acjbaber',
#  'ack aelaw',
#  'ack klaw',
#  'ackc',
#  'acken',
#  'ackerman wapa',
#  'ackertdm',
#  'ackertdm donna ackert cackertdm',
#  'aclair moheck',
#  'aclark firstcallassociates',
#  'aclemons',
#  'aclemons notes',
#  'aclhart',
#  'acnnrg cta',
#  'acohrs',
#  'acollin',
#  'acomnes prodigy',
#  'aconge pdq',
#  'aconne',
#  'acook',
#  'acook utilicorp',
#  'acooper columbus',
#  'acormier vicr',
#  'acostlow',
#  'acqm wtkmafd',
#  'acrawford sonypictures',
#  'acrosswell crosswellproperties',
#  'acrump dc',
#  'acrysdale mba',
#  'acsutton',
#  'act',
#  'actforchange com',
#  'activeleads eudoramail',
#  'activelist activestate',
#  'activelist admin eactivestate',
#  'activenrma eamunet',
#  'acton',
#  'acton jan cjacton crai',
#  'acullen firstcallassociates',
#  'aculver',
#  'acunningham technologicp',
#  'acuou iobox efi',
#  'acurles',
#  'ad ef dd da',
#  'ad fd',
#  'ada clickaction',
#  'ada takahashi cada kochgallery',
#  'adadson',
#  'adahlke',
#  'adam',
#  'adam and nicole lesser cfurie rocketmail',
#  'adam bauer',
#  'adam bayer',
#  'adam borison',
#  'adam brulinski',
#  'adam buffy',
#  'adam cooper',
#  'adam dushinske',
#  'adam dyerson cadam edyerson gfinet',
#  'adam eudoramail',
#  'adam fauten xtoenergy',
#  'adam giannone',
#  'adam gross',
#  'adam johnson',
#  'adam kulick',
#  'adam metry',
#  'adam overfield',
#  'adam plager',
#  'adam senn',
#  'adam siegel',
#  'adam stevens',
#  'adam texas',
#  'adam thomas',
#  'adam umanoff',
#  'adam wais',
#  'adam watts',
#  'adam_metter@sfmny.com',
#  'adambob stat rice',
#  'adamik',
#  'adamk ml',
#  'adamk nepco',
#  'adams jacqueline cjacqueline eadams cinergy',
#  'adams rg',
#  'adamsd hongkong',
#  'adamsholly netscape',
#  'adamson',
#  'adamsotj bp',
#  'adan garcia',
#  'adanker kayescholer',
#  'adarsh',
#  'adarsh vakharia',
#  'adauzat lsu',
#  'adavis',
#  'adavis oppd',
#  'adavis reliant',
#  'aday',
#  'adayao',
#  'adc',
#  'adc nearbycafe',
#  'add',
#  'adda cf bcda',
#  'addison',
#  'addison donavon',
#  'addvancepq',
#  'addyee caddyee',
#  'adeere mcguirewoods',
#  'adel robinson',
#  'adela briner',
#  'adelag amhms',
#  'adele amurao',
#  'adele raspe',
#  'adele zuroff',
#  'adeller ercot',
#  'adelligatti brobeck',
#  'adels',
#  'ademulling fraserstryker',
#  'ademuzio',
#  'adenwala',
#  'ader',
#  'aderich exxon sprint',
#  'adesell nyiso',
#  'adesousa',
#  'adeyinka',
#  'adf marval ar',
#  'adicapr utilicorp',
#  'adicapri utilicorp',
#  'adicapri utilicorp dicaprio angela cadicapri',
#  'adil jaffry',
#  'adiproperties',
#  'adiza',
#  'admin eba',
#  'admin fsddatasvc',
#  'admin houstontech',
#  'admin iwin',
#  'admin johnscotti',
#  'admin neteller',
#  'admin newmn blue',
#  'administrator hollings senate',
#  'administrator internetex',
#  'administrator mailman',
#  'administrator midwestdirectories',
#  'administrator techxans',
#  'adminsec centralhouston',
#  'admission jhubc it',
#  'admission jhuwash jhu',
#  'admissions amunet',
#  'admittedf evmba',
#  'adnan and maylynn khan cthe fkhans',
#  'adnan khan cakhan khanventures',
#  'adnan patel',
#  'adnan rajab',
#  'adnankkhan',
#  'adocwra',
#  'adonnell prmllp',
#  'adonnelly prmllp',
#  'adonoho',
#  'adorazi',
#  'adove enogex',
#  'adrial',
#  'adrial boals',
#  'adrian clark caclark firstcallassociates',
#  'adrian mancebo',
#  'adrian mitchell',
#  'adrian montague',
#  'adrian schulzeff shrwd',
#  'adrian woolcock',
#  'adriana celedon',
#  'adriana cortes',
#  'adriana domingues',
#  'adriana fabregas',
#  'adriana peterson',
#  'adriana wynn',
#  'adriane',
#  'adriane moratto',
#  'adriane schultea',
#  'adrianne engler',
#  'adriantm',
#  'adrienneanderson aec',
#  'adsalas',
#  'adsmith brobeck',
#  'adsproject caiso',
#  'aducan kilpatrickstockton',
#  'aduncan kilstock',
#  'adupont',
#  'aduran',
#  'adushins',
#  'advadv ruraltel',
#  'advapl vsnl',
#  'adventurehf pdq',
#  'adver passionboys',
#  'advisory board cng',
#  'advisory board dom',
#  'adwelch',
#  'ae',
#  'ae ba',
#  'ae ed',
#  'aea de',
#  'aeabbott',
#  'aeanabors',
#  'aeastwoo',
#  'aebrown santeecooper',
#  'aed',
#  'aed fc',
#  'aedc',
#  'aedison',
#  'aedison bracepatt',
#  'aeeba',
#  'aef ba dc',
#  'aefurcht facstaff ewisc caefurcht',
#  'aei bi fupdates www ebrook',
#  'aei bi updates www brook',
#  'aei fupdate caei update eorg',
#  'aei update',
#  'aeisens',
#  'aejsr',
#  'aelia isda eur',
#  'aem bomchil ar',
#  'aeng aoshouston',
#  'aengler',
#  'aerb biehlco',
#  'aervin',
#  'aescami',
#  'aet pge',
#  'aevanloon',
#  'af',
#  'af ab',
#  'af ae ce',
#  'af aef',
#  'af bd',
#  'af ec',
#  'af fc',
#  'af fcada cc',
#  'af fe',
#  'af ssclxjfagjsrr travelocity',
#  'af@tfts.tozzini.com.br',
#  'af@tozzini.com.br',
#  'afa be',
#  'afa eea abfcd',
#  'afac aee bc',
#  'afac tfts tozzini br',
#  'afac tozzini br',
#  'afairley',
#  'afarinacci prebon',
#  'afastow',
#  'afay',
#  'afb ae',
#  'afc ebd',
#  'afdedb',
#  'afellin',
#  'afernan entergy',
#  'aff db ee aab',
#  'affelt',
#  'afffd feae eaf',
#  'affiliates',
#  'afield mariner',
#  'afilas keyspanenergy',
#  'afinch iasco',
#  'afinch natsource',
#  'afishman bracepatt',
#  'afitzpat',
#  'aflower csc',
#  'aforbess wcenviro',
#  'aforster',
#  'afoster hampshire cafoster',
#  'afowler arcfinancial',
#  'afried cantor',
#  'afsc angelflightsc',
#  'aftab saleem',
#  'afterchristmas fspecial',
#  'afternic cafternic fsupport adm echtah',
#  'afulco goodkindinc',
#  'afw blakes',
#  "ag o'connor",
#  'aga rehman',
#  'agaddis',
#  'agaddis utexas',
#  'agallers cagallers',
#  'agamboa mayerbrown',
#  'agapetvl swbell',
#  'agarner reliant',
#  'agarwal',
#  'agarwalla',
#  'agarza wsbc',
#  'agatewood aristotle',
#  'agatha',
#  'agatha tran',
#  'agaur tjbc ecoj cagaur',
#  'agave pvtnetworks',
#  'agaw gilbertglobal',
#  'agbriggs adamswells',
#  'agbriggs adamswells cagbriggs',
#  'agcdu triax',
#  'ageevarghese hesinet',
#  'agelber gelbercorp',
#  'agency pce',
#  'agendas',
#  'agenergy aeca',
#  'agent',
#  'agent manager',
#  'agentrapid pacbell',
#  'aggar',
#  'aggie chic',
#  'aggie swbell',
#  'aggieengineer',
#  'aggienetwork',
#  'agheb',
#  'agiannon',
#  'agiglia sempratrading',
#  'aglazner fmtn',
#  'agnew',
#  'agnews cme americangreetings',
#  'agoddard nisource',
#  'agoldberg lgl twc',
#  'agonzale',
#  'agosalia',
#  'agostino',
#  'agovenar govadv',
#  'agranad',
#  'agrasso ml',
#  'agreene mfah',
#  'agreer',
#  'agregorich asarco',
#  'agregory globeop',
#  'agriffin texicannaturalgas',
#  'agrovil huglushotguns',
#  'agrubb calnurses',
#  'agruber tindallfoster',
#  'agruden naturabella',
#  'aguiar usourceonline',
#  'aguilera peon maria teresa',
#  'aguille',
#  'aguirre',
#  'agustin perez',
#  'ahafner csc',
#  'ahampshire cowan howard',
#  'ahand tambank cahand',
#  'aharpaz doverinstrument',
#  'aharpaz doverinstrument caharpaz',
#  'aharrington deltapower',
#  'ahartman cisco',
#  'ahauser txpetrochem',
#  'ahawtho',
#  'ahayman stblaw',
#  'ahcl dynegy',
#  'ahealypo',
#  'ahefferm',
#  'ahegger pdq',
#  'ahenders aglresources',
#  'ahenry ev',
#  'aherasim',
#  'aherbst utilisenergy',
#  'ahernan',
#  'ahespenh cahespenh',
#  'ahfs mot',
#  'ahill',
#  'ahimsaom cs cahimsaom',
#  'ahkalbacher njresources',
#  'ahl',
#  'ahmad farooqi',
#  'ahmed',
#  'ahmedxii',
#  'ahockman attbroadband cahockman',
#  'ahopp mercator cahopp',
#  'ahrach',
#  'ahsan',
#  'ahsieh',
#  'ahuang',
#  'ahuble',
#  'ahuertas',
#  'ahuertas uk',
#  'aiaz kazi',
#  'aiaz kazi versata',
#  'aiazkazi hotbot',
#  'aibrahi',
#  'aibrahim',
#  'aida alvarez',
#  'aidan.mcnulty@riskmetrics.com',
#  'aidenfire mediaone',
#  'aiessi poseidon',
#  'aile caile mailman eenron',
#  'aile mailman',
#  'aimee',
#  'aimee lannou',
#  'aimee shek',
#  'aimr scholarship fund caimr bbh eviamedialinq',
#  'ain worldnet att',
#  'airam',
#  'airam arteaga',
#  'airmail xmr',
#  'airmessage',
#  'airphotodave',
#  'aisabella nyiso',
#  'aisha jamal',
#  'aisha uh',
#  'aishikawa socalgas ishikawa angie tpagi caishikawa',
#  'aivvxx',
#  'aiysha billings cabillings knowledgeinenergy',
#  'ajackson btutilities',
#  'ajaffry',
#  'ajafry',
#  'ajain worldbank',
#  'ajarret',
#  'ajax planet save cajax',
#  'ajay jagsi',
#  'ajay thomas',
#  'ajbarnard',
#  'ajc infohwy',
#  'ajenkins lanlaw',
#  'ajfintz snopud',
#  'ajgillett',
#  'ajit gill',
#  'ajlbrgaeimh drqpu pauf iokfr travelocity',
#  'ajm@lehman.com',
#  'ajnovero iwon',
#  'ajoe',
#  'ajohnso',
#  'ajohnson',
#  'ajones diamondscientific',
#  'ajones uwtgc',
#  'ajpace',
#  'ajulian',
#  'ak',
#  'akanji',
#  'akarabat',
#  'akariot nbg gr',
#  'akasha bibb',
#  'akasha redrick',
#  'akashabibb',
#  'akatvod',
#  'akatz eei',
#  'akatz eei orgimceanotes andy katz cakatz eorg',
#  'akawaja',
#  'akeel mariner',
#  'akeiser rocketmail',
#  'akhan khanventures',
#  'akholmes swidlaw',
#  'akht sjzvc',
#  'akidd marathonoil',
#  'akiko hirano',
#  'akikomark rocketmail',
#  'akikoo attglobal',
#  'akimball bracepatt',
#  'akin',
#  'aklein kelleydrye',
#  'aklodow alleghaenyenergy',
#  'aklodow alleghaneyenergy',
#  'aklodow alleghenyenergy',
#  'aknittel ford',
#  'akoehle',
#  'akoelemay cogc',
#  'akoelemay coge',
#  'akoenig bksklaw',
#  'akoenig hhw law',
#  'akohler wolfblock',
#  'akorth',
#  'akorth riveroaksimaging',
#  'akose',
#  'akrachman bracepatt',
#  'akratish gscpartners',
#  'akrone',
#  'akwete hines',
#  'akyles hcde texas',
#  'al alexanderson',
#  'al amyn valliani',
#  'al arfsten carfsten bflassociates',
#  'al colangelo',
#  'al epollard newpower',
#  'al garcia',
#  'al herrmann',
#  'al maawali',
#  'al miralles',
#  'al mitchell',
#  'al pollard',
#  'al sayed adgas ae',
#  'al shaver',
#  'al v andrew cmu',
#  'alaadin suliman',
#  'alabbe',
#  'alacartesw',
#  'alafave',
#  'alain diza',
#  'alaina doublemo',
#  'alamo',
#  'alamonsoff riskwaters',
#  'alamonsoff watersinfo',
#  'alan',
#  'alan aronowitz',
#  'alan aronowitz hou',
#  'alan batt oxy',
#  'alan baumbusch',
#  'alan behrens',
#  'alan black',
#  'alan bransgrove',
#  'alan brumbaugh',
#  'alan buckwalter',
#  'alan chapman',
#  'alan chen',
#  'alan childress',
#  'alan coad',
#  'alan comnes',
#  'alan comnes pdx',
#  'alan engberg',
#  'alan enventure',
#  'alan epud',
#  'alan jones',
#  'alan jr',
#  'alan julson cvze szx verizon',
#  'alan kean',
#  'alan killion',
#  'alan kohler cakohler wolfblock',
#  'alan larsen',
#  'alan lucks clucks alucks',
#  'alan mcgaughy',
#  'alan muntz',
#  'alan nahman',
#  'alan nueman',
#  'alan pacbell',
#  'alan prenoveau ngsinc',
#  'alan progas',
#  'alan quaintance',
#  'alan reid pcp',
#  'alan seidelmann anderson ucla',
#  'alan sides',
#  'alan stringer',
#  'alan taylor anadarko',
#  'alan tippett',
#  'alan waugh',
#  'alan wayne',
#  'alan yudkowsky',
#  'alanderson',
#  'alanderson enmergy',
#  'alangfel',
#  'alannou',
#  'alarsen120@aol.com @ enron',
#  'alaska web',
#  'alatorre',
#  'alaw avistaenergy',
#  'alazar allenco',
#  'alb kri',
#  'albergor haynesboone',
#  'albernita travis',
#  'albers',
#  'albert',
#  'albert escamilla',
#  'albert hernandez',
#  'albert luc',
#  'albert mcclaran',
#  'albert wood',
#  'alberta realtime',
#  'alberto carreno',
#  'alberto cota',
#  'alberto jaramillo putnaminv',
#  'alberto jimenez',
#  'alberto levy',
#  'albino lopez',
#  'albrecht',
#  'albrecht jason emc',
#  'albuquerque',
#  'alcantara',
#  'alcott',
#  'alden zeitz',
#  'aldinger',
#  'aldis',
#  'aldis russell',
#  'aldpal',
#  'ale',
#  'alec cohen',
#  'aleck',
#  'aleck dadson',
#  'aleerhea',
#  'alejandra',
#  'alejandra chavez',
#  'alejandrachavez',
#  'alejandro hernandez',
#  'aleka scott pngc',
#  'alemant epenergy',
#  'alender',
#  'alents',
#  'aleo powermerchants',
#  'aleonard caiso',
#  'alerios entelchile',
#  'alerts breakingnews',
#  'alerts equityalert',
#  'alerts finance',
#  'alerts stock',
#  'alerts stockselector',
#  'alessandro',
#  'alevwho mediaone calevwho',
#  'alewis',
#  'alewis adobe',
#  'alewis cts',
#  'alewis daystar',
#  'alewis demon uk',
#  'alewis gnn',
#  'alewis indy',
#  'alewis infi',
#  'alex',
#  'alex bandini',
#  'alex ehuang',
#  'alex engles csi',
#  'alex eplanning',
#  'alex finmath',
#  'alex fuller',
#  'alex goldberg',
#  'alex henry',
#  'alex hidalgo',
#  'alex holland',
#  'alex hsieh',
#  'alex huang',
#  'alex lopeznegrete',
#  'alex macd',
#  'alex mcleish',
#  'alex niemer',
#  'alex parsons',
#  'alex parsons euenronxgate',
#  'alex perkins',
#  'alex saldana',
#  'alex schott cfatschott',
#  'alex shea',
#  'alex sugaoka',
#  'alex tartakovski',
#  'alex webspan',
#  'alex wong',
#  'alexamms sce',
#  'alexander',
#  'alexander eydeland',
#  'alexander fusco',
#  'alexander gonzales',
#  'alexander martinez',
#  'alexander mcelreath',
#  'alexander personnel',
#  'alexander perwich',
#  'alexandra cameron',
#  'alexandra saler',
#  'alexandra tgharchs',
#  'alexandra tgharchs calexandra',
#  'alexandra villarreal',
#  'alexandra villarreal cavillarreal err',
#  'alexandre bueno',
#  'alexandria w valentine cngp cng',
#  'alexanms sce',
#  'alexdinh',
#  'alexdugas',
#  'alexeaton',
#  'alexeaton calexeaton',
#  'alexh alumni rice',
#  'alexhsu zahrsecurities',
#  'alexia',
#  'alexia gonzales',
#  'alexia pearce',
#  'alexilex@aol.com',
#  'alexios kollaros',
#  'alexis calexis',
#  'alexis carroll',
#  'alexizann',
#  'alexm amerexenergy',
#  'alexm artex',
#  'alexm calpine',
#  'alexmacdonald netzero',
#  'alexminh',
#  'alexus rhone',
#  'alezhsu zahrsecurities',
#  'alfaro',
#  'alfie prebon uk',
#  'alfonso trabulsi',
#  'alfred',
#  'alfred gilman',
#  'alfred koenig cakoenig hhw law',
#  'alfred pennisi',
#  'alfredo',
#  'alfredo dvinci',
#  'alfredo fernandez',
#  'alfredo goyburu',
#  'alfredo huertas',
#  'algoreply algorithmics',
#  'alhamd alkhayat',
#  'ali ahmed',
#  'ali khoja',
#  'ali lloyd',
#  'ali miremadi',
#  'ali panix cali',
#  'ali rodol',
#  'aliban uol eco ees',
#  'alice barton cenergy flist spencerstuart',
#  'alice grubb (e-mail)',
#  'alice gruber cagruber tindallfoster',
#  'alice hritz',
#  'alice johnson',
#  'alice wimberly',
#  'alice wright',
#  'alicethuvan',
#  'alicia allrecipes calicia',
#  'alicia goodrow',
#  'alicia jones',
#  'alicia lenderman',
#  'alicia perkins',
#  'aliciajansen',
#  'alidogo',
#  'alienenvoy',
#  'aligazarine',
#  'aline holland zenith ehowellcorp',
#  'alingenf sel',
#  'alippin arco',
#  'alisa christensen',
#  'alisa green',
#  'alisears',
#  'alisha bp',
#  'alisha guerrero',
#  'alisha mahabir',
#  'alisha mahavir',
#  'alishec calishec',
#  'alison',
#  'alison campbell',
#  'alison campbell eott',
#  'alison donnelly',
#  'alison heer ddouglas k or',
#  ...]

# %%
df_ = pd.DataFrame(index=persons, data= {"sent": [0]*len(persons),
                                         "received": [0]*len(persons)})
df_.head(10)
# Out:
#                                       sent  received
#                                          0         0
# martha braddy                            0         0
# goodmanla                                0         0
# william tribe ml                         0         0
# black                                    0         0
# olson                                    0         0
# rwhiterussian                            0         0
# frank ebillington oatiinc                0         0
# investorrelations communications amd     0         0
# monanmac netzero                         0         0

# %%
# def func(x, df):
# #     df_.sent[x.sender] += 1
#     df_.received[x.recipients] += 1
    
# df.apply(func, axis=1, args=(df_,))
# df_

# %%
df.head()
# Out:
#              datetime              sender                       recipients  \
# 0 1998-05-27 17:31:00  christopher behney  [toni p schulenburg, mary hain]
# 1 1998-10-30 17:43:00   mark legal taylor  [marc.r.cutler@bankamerica.com]
# 2 1998-10-30 17:56:00   mark legal taylor  [marc.r.cutler@bankamerica.com]
# 3 1998-10-30 18:02:00   mark legal taylor                    [shari stack]
# 4 1998-10-30 19:06:00   mark legal taylor  [marc.r.cutler@bankamerica.com]
#
#          date      time
# 0  1998-05-27  17:31:00
# 1  1998-10-30  17:43:00
# 2  1998-10-30  17:56:00
# 3  1998-10-30  18:02:00
# 4  1998-10-30  19:06:00

# %%
df_recipients.head()
# Out:
# Empty DataFrame
# Columns: [datetime, recipient]
# Index: []

# %%
# Out:
#               datetime                                          recipient
# 0  1998-05-27 17:31:00                                 toni p schulenburg
# 1  1998-05-27 17:31:00                                          mary hain
# 2  1998-10-30 17:43:00                      marc.r.cutler@bankamerica.com
# 3  1998-10-30 17:56:00                      marc.r.cutler@bankamerica.com
# 4  1998-10-30 18:02:00                                        shari stack
# 5  1998-10-30 19:06:00                      marc.r.cutler@bankamerica.com
# 6  1998-11-02 21:32:00                                          yao apasu
# 7  1998-11-03 13:12:00                                       brent hendry
# 8  1998-11-03 13:12:00                                  mark legal taylor
# 9  1998-11-04 12:31:00                      marc.r.cutler@bankamerica.com
# 10 1998-11-04 13:59:00                                        paul simons
# 11 1998-11-04 19:03:00                           cynthia c sandherr@enron
# 12 1998-11-04 19:03:00                               jeffrey keeler@enron
# 13 1998-11-04 19:03:00                                stacey bolton@enron
# 14 1998-11-04 19:21:00                                            mtaylor
# 15 1998-11-05 14:35:00                                        justin boyd
# 16 1998-11-09 18:50:00                        mark - ect legal taylor@ect
# 17 1998-11-09 18:50:00                                         doug leach
# 18 1998-11-09 18:50:00  margarita g jannasch/enron_development at enro...
# 19 1998-11-13 14:07:00                                         tana jones
# 20 1998-11-13 18:09:00                                          per sekse
# 21 1998-11-19 11:41:00                                          per sekse
# 22 1998-11-19 16:34:00                                            mtaylor
# 23 1998-11-19 16:42:00                                       brent hendry
# 24 1998-11-19 16:49:00                                       brent hendry
# 25 1998-11-19 17:19:00                                      michelle cash
# 26 1998-11-19 18:24:00                                       brent hendry
# 27 1998-11-19 18:24:00                                      michelle cash
# 28 1998-11-19 20:46:00                                sara davidson@enron
# 29 1998-11-19 20:58:00                                          anita fam
# ..                 ...                                                ...
# 58 1998-12-02 13:47:00                                    richard sanders
# 59 1998-12-02 13:47:00                                    kimberly b dees
# 60 1998-12-02 13:57:00                                     alan aronowitz
# 61 1998-12-02 13:57:00                                        paul simons
# 62 1998-12-02 13:57:00                                       scott sefton
# 63 1998-12-02 13:57:00                                          yao apasu
# 64 1998-12-02 15:24:00                                         tana jones
# 65 1998-12-02 18:40:00                                       scott sefton
# 66 1998-12-02 18:40:00                                     alan aronowitz
# 67 1998-12-02 18:40:00                                        paul simons
# 68 1998-12-02 18:40:00                                          yao apasu
# 69 1998-12-02 19:55:00                                        paul simons
# 70 1998-12-02 19:55:00                                       scott sefton
# 71 1998-12-02 19:55:00                                     alan aronowitz
# 72 1998-12-02 19:55:00                                          yao apasu
# 73 1998-12-03 17:21:00                                  janet dobernecker
# 74 1998-12-03 21:27:00                                      martin rosell
# 75 1998-12-03 21:31:00                                  janet dobernecker
# 76 1998-12-03 21:38:00                                         tana jones
# 77 1998-12-03 21:38:00                                            mtaylor
# 78 1998-12-04 11:15:00                                        marie heard
# 79 1998-12-04 11:15:00                                  janet dobernecker
# 80 1998-12-04 19:05:00                      marc.r.cutler@bankamerica.com
# 81 1998-12-05 19:30:00                                        paul simons
# 82 1998-12-05 19:30:00                                      mark haedicke
# 83 1998-12-05 19:30:00                                     alan aronowitz
# 84 1998-12-05 19:30:00                                      jeffrey hodge
# 85 1998-12-05 19:30:00                                  mark legal taylor
# 86 1998-12-08 10:59:00                                       scott sefton
# 87 1998-12-09 11:14:00                                         tana jones
#
# [88 rows x 2 columns]

# %%
df.sender[df.sender.apply(lambda x: x == ".")]
# Out:
# 160519    .
# 168069    .
# 177449    .
# Name: sender, dtype: object

# %%
text = df.recipients[29]
text

# %%
pattern = "\|?(.+?)(?=\|)"
match = re.findall(pattern, text)
match

# %%
df.recipients = df.recipients.str.split("|")

# %%
def func(x):
    print(x.recipients)
df.apply(func=func, axis=1)    
# df.sender.apply(lambda x: print(len(x)))

# %%
# get unique person names/emails from both sender and recipients columns
persons = set(df.sender.values)
def func(x, unique_set):
    unique_set.update(x)
df.recipients.a
pply(update_uniques, args=(persons,))
persons

# %%
pd.pivot_table(df, index=["sender"], values="recipients", aggfunc=len)

# %%
df.sender.unique().shape

# %%
df.groupby("sender")["sender"].count()

# %%
[True if "mark legal taylor" in elem else False for urser in df.for elem in df.recipients]

# %%
df.recipients
